# %% [markdown]
# xf

# %% [markdown]
# # For when i move file in dataanalysis
#
# import sys
# import os
#
# #getting the name of the directory
# #where the this file is present.
# current = os.path.dirname(os.path.realpath(__file__))
#
# #Getting the parent directory name
# #where the current directory is present.
# parent = os.path.dirname(current)
#
# #adding the parent directory to
# #the sys.path.
# sys.path.append(parent)
#
# #now we can import the module in the parent
# #directory.
# import pybert

# %%
# importing
#from pybert.preprocessing.preprocessor import EnglishPreProcessor
#from pybert.configs.basic_config import config
#from pybert.io.task_data import TaskData
from preprocessor import EnglishPreProcessor


import pickle
import pprint
import pandas as pd

# %%
#PREPROCESSING IN PAPER: lower-casing, stopword removal, and rare word remova

role = "?:UPPER:?X You have several years of experience in digital (customer) data analysis. You have knowledge/experience of digital marketing, e-commerce and e-care, including web analytics, social media and conversion marketing. You have experience with the use of analytical tools (preferably Adobe Analytics). Knowledge of tag management, Adobe Experience Manager and Adobe Audience Manager is a strong asset. You are fluent in PowerPoint and Excel and have a basic knowledge of web technologies. You have good analytical skills. You are a critical thinker and a good problem solver. You are a real team player who can work well with colleagues from different teams, both from a business and a more technical background. You have strong communication and presentation skills. You love to make data transparent for business and enjoy taking on less experienced colleagues. You are willing to further develop skills in a team-oriented, fast-changing environment."

company_info_NTU = "World's Top Young University\nA research-intensive public university, Nanyang Technological University, Singapore (NTU Singapore) has 33,000 undergraduate and postgraduate students in the colleges of Engineering, Business, Science, and Humanities, Arts and Social Sciences, and its Interdisciplinary Graduate School. NTU\u2019s Lee Kong Chian School of Medicine was established jointly with Imperial College London.\nMeteoric rise in international academic reputation\u00a0?\nIn 2018, NTU was placed 12th globally in the Quacquarelli Symonds (QS) World University Rankings. It was also ranked the world\u2019s best young university (under 50 years old) by QS for the fifth consecutive year. In addition, NTU was named the world\u2019s fastest rising young university by Times Higher Education in 2015.\nIn engineering and technology, NTU is ranked 5th worldwide in the QS World University Rankings by Subject 2018. With six schools, NTU\u2019s College of Engineering is among the top nine globally for research output and the 5th most cited in the world (Essential Science Indicators 2017).\u00a0?\nMirroring this success is the College of Science, whose young chemistry department is ranked 10th among universities in the Nature Index 2018. Boosted by research at the Lee Kong Chian School of Medicine, NTU is also strengthening its foothold in areas such as biomedicine and life sciences.\nThe well-established Nanyang Business School is regularly featured among the leading business schools in Asia, with its MBA programme consistently rated top in Singapore since 2004 by The Economist.\nInnovative learning\nIn higher education, NTU is driving new pedagogies so that millennials can learn more effectively in this digital age. Part of NTU's education strategy is the flipped classroom model of learning. The centrepiece of this new way of learning is The Hive, a groundbreaking learning facility that has been described by CNN as having redefined the traditional classroom.\u00a0\nInnovative education initiatives also include signature programmes such as Renaissance Engineering Programme, CN Yang Scholars Programme, NTU-University Scholars Programme. Designed for high-achieving students, these programmes offer a multidisciplinary curriculum, guidance by top faculty, interdisciplinary and intensive research opportunities, overseas exposure, as well as dialogues with world-class scientists and industry leaders.?\nSet up jointly with Imperial College London, NTU's medical school, is grooming a new generation of doctors to meet the healthcare needs of Singapore.\nResearch impact\nKnown for research excellence and technological innovation, NTU leads the top Asian universities in normalised research citation impact (Clarivate Analytics\u2019 InCites 2016). In the 2018\u00a0Nature Index, NTU is placed 29th among the world's universities and first in Singapore.\nNTU's five-year strategic plan, NTU 2020, builds on strong foundations of NTU 2015 and aims to propel NTU to greater heights of research excellence. The plan focuses on five key research thrusts \u2013 Sustainable Earth, Global Asia, Secure Community, Healthy Society and Future Learning. The areas leverage NTU\u2019s diverse strengths, particularly its longstanding expertise in engineering, business and education, and the interfaces these have with various disciplines such as in healthcare, science and the humanities. NTU\u2019s sustainability initiatives have clinched significant competitive research funding and the university is already a global leader in this area.\n"


#s = "DataAnalysis/resumes_dataset_test.csv"
s = "resumes_dataset_test.csv"

preprocessor = EnglishPreProcessor() #min_len=2,stopwords_path=None
content_file_str = ""
with open(s, "r") as f:
        content_file_str = f.readlines()

print("content_file_str:\n",content_file_str)

cleaned = ""
for line in content_file_str:
        cleaned+= preprocessor(line) + "\n"

#data_preprocessor = TaskData()
#cleaned = data_preprocessor.read_data("DataAnalysis/resumes_dataset_test.csv",
#                                            preprocessor=EnglishPreProcessor(),
#                                            is_train=True)

with open("resumes_preprocessed_test.txt", "w") as f:
        f.write(cleaned)

print("raw:\n",s)
print("preprocessed:\n",cleaned)
# Out:
# content_file_str:
#  [',text,skills_required\n', '0,"Database Administrator Database Administrator Database Administrator - Family Private Care LLC Lawrenceville, GA A self-motivated Production SQL Server Database Administrator who possessesÂ\xa0 strong analytical and problem solving skills. My experience includes SQL ServerÂ\xa0 2005, 2008 and 2012, 2014, SSIS, as well as clustering, mirroring, and highÂ\xa0 availability solutions in OLTP environments. I am proficient in database backup,Â\xa0 recovery, performance tuning, maintenance tasks, security, and consolidation.Â\xa0 I am confident that I would make a beneficial addition to any company. Over theÂ\xa0 course of my career thus far, I have designed databases to fit a variety of needs,Â\xa0 successfully ensured the security of those databases, problem-solved in order to meetÂ\xa0 both back-end and front-end needs, installed and tested new versions databaseÂ\xa0 management systems, customized and installed applications and meticulouslyÂ\xa0 monitored performance for the smoothest front-end experience possible. During myÂ\xa0 5 to 6 years working with databases. Work Experience Database Administrator Family Private Care LLC - Roswell, GA April 2017 to Present Confirm that backups have been made and successfully saved to a secureÂ\xa0 locationÂ\xa0 Planning for backup and recovery of database information.Â\xa0 Maintaining archived data Backing up and restoring databases, ContactingÂ\xa0 database vendor for technical support Generating various reports by querying from database as per needed.Â\xa0 Managing and monitoring data replication. Acting as liaison with users HighÂ\xa0 Availability or Disaster Recovery Logs - Check your high availability and/or disaster recovery process logs. Depending on the solution (Log Shipping,Â\xa0 Clustering, Replication, Database Mirroring, CDP, etc.) that you are usingÂ\xa0 dictates what needs to be checked. Correcting errors and make necessaryÂ\xa0 modificationÂ\xa0 Modify existing databases and database management systems or directÂ\xa0 programmers and analysts to make changes.Â\xa0 Work as part of a project team to coordinate database development and seeÂ\xa0 termite project scope and limitationsÂ\xa0 Train Users and answers questions.Â\xa0 Approve, schedule, plan, and supervise the installation and testing of newÂ\xa0 products and improvements to computer systems, such as the installation of new databases.Â\xa0 Review Procedures in Database management system manuals for makingÂ\xa0 changes to database.Â\xa0 Select and enter codes to monitor database performance and to createÂ\xa0 production database.Â\xa0 Check the backup failure alerts, correct the errors and rerun the backups.Â\xa0 Review the average duration of backup, any significant changes occurredÂ\xa0 investigates on this.Â\xa0 Most of the time it happens due to networking low bandwidth Validate the backup files using restore verify only.Â\xa0 I create jobs to take care of the task and to send a notification if it fails to verifyÂ\xa0 any backup.Â\xa0 Monitoring all backup and log history is cleaning when designed. Find out the newly added databases and define the backup plan. I do verify the free space onÂ\xa0 each drive on all servers, If there is significant variance in free space from the day before, research the cause of the free space fluctuation and resolve ifÂ\xa0 necessary, Often times, log files will grow because of monthly jobs automate through a job. The job runs for every one hour and reports any drive which isÂ\xa0 having less than 15 % of free space.Â\xa0 I can design a SSRS report to showcase and review the delta values.Â\xa0 Confirm all servers/databases are up and running fine. Usually in an EnterpriseÂ\xa0 Database Environment Third Party Tools are used to monitor Servers. ForÂ\xa0 database monitoring, I can design a native SQL Server solution using T-SQLÂ\xa0 code and a maintenance plan, it run min by min and send an email to DBAÂ\xa0 team if it is not able to connect to any of the  ...
# raw:
#  resumes_dataset_test.csv
# preprocessed:
#  textskills_required
# 0database administrator database administrator database administrator   family private care llc lawrenceville ga a self motivated production sql server database administrator who possessesâ strong analytical and problem solving skills my experience includes sql serverâ 2005 2008 and 2012 2014 ssis as well as clustering mirroring and highâ availability solutions in oltp environments i am proficient in database backupâ recovery performance tuning maintenance tasks security and consolidationâ i am confident that i would make a beneficial addition to any company over theâ course of my career thus far i have designed databases to fit a variety of needsâ successfully ensured the security of those databases problem solved in order to meetâ both back end and front end needs installed and tested new versions databaseâ management systems customized and installed applications and meticulouslyâ monitored performance for the smoothest front end experience possible during myâ 5 to 6 years working with databases work experience database administrator family private care llc   roswell ga april 2017 to present confirm that backups have been made and successfully saved to a secureâ locationâ planning for backup and recovery of database informationâ maintaining archived data backing up and restoring databases contactingâ database vendor for technical support generating various reports by querying from database as per neededâ managing and monitoring data replication acting as liaison with users highâ availability or disaster recovery logs   check your high availability and or disaster recovery process logs depending on the solution log shippingâ clustering replication database mirroring cdp etc that you are usingâ dictates what needs to be checked correcting errors and make necessaryâ modificationâ modify existing databases and database management systems or directâ programmers and analysts to make changesâ work as part of a project team to coordinate database development and seeâ termite project scope and limitationsâ train users and answers questionsâ approve schedule plan and supervise the installation and testing of newâ products and improvements to computer systems such as the installation of new databasesâ review procedures in database management system manuals for makingâ changes to databaseâ select and enter codes to monitor database performance and to createâ production databaseâ check the backup failure alerts correct the errors and rerun the backupsâ review the average duration of backup any significant changes occurredâ investigates on thisâ most of the time it happens due to networking low bandwidth validate the backup files using restore verify onlyâ i create jobs to take care of the task and to send a notification if it fails to verifyâ any backupâ monitoring all backup and log history is cleaning when designed find out the newly added databases and define the backup plan i do verify the free space onâ each drive on all servers if there is significant variance in free space from the day before research the cause of the free space fluctuation and resolve ifâ necessary often times log files will grow because of monthly jobs automate through a job the job runs for every one hour and reports any drive which isâ having less than 15 % of free spaceâ i can design a ssrs report to showcase and review the delta valuesâ confirm all servers databases are up and running fine usually in an enterpriseâ database environment third party tools are used to monitor servers forâ database monitoring i can design a native sql server solution using t sqlâ code and a maintenance plan it run min by min and send an email to dbaâ team if it is not able to connect to any of the database in the instance i do design a native scripts using t sql to monitor replication mirroring logâ shipping database administrator incomm alpharetta   alpharetta ga january 2014 to february 2017 * responsible for administering and maintaining over 150 database servers of productio ...
# 1database administrator database administrator sql server database administrator houston tx database administratorâ over five years of experience in database management systems administration expert at developing and maintaining database with strong background of working on high end servers i would like to establish a fulfilling proactive career and assume every increasing responsibility in the course of time work experience database administrator intercontinental registry   lagos gu december 2008 to august 2011 responsibilitiesâ key responsibilitiesâ planning developmentâ involved in analyzing business requirements developing and designing data modelsâ â€¢ provided and designed db tools to assist in the database management transactions and processing environmentsâ â€¢ assessed and executed implementing of new technologiesâ â€¢ worked in coordination with company developers and project managersâ â€¢ developed training programs and trained technical support and applications personnel to utilize on line databases environment processâ â technical supportâ monitored performance and capacity to provide resolutions to system problemsâ â€¢ provided technical support for sql database environment by overseeing databases development and organizationâ â€¢ communicated regularly with staff to ensure smooth flow of information from sql databaseâ â€¢ created database with back up systemâ â maintenanceâ â€¢ monitored data availability for faster query response by userâ â€¢ designed conceptual schema as per the client needsâ â€¢ looked after the security of company data from external access and threatsâ â€¢ tested and installed latest versions of database management systems in firmâ â€¢ granted access to users as per their needs and requirementsâ â skills usedâ sql server management studiovisual studio education bsc in computer science lagos state university   lagos gu skills sql microsoft powerpoint windows xp microsoft office assembly language microsoft windows 7 c c# visual basic and java programming microprocessors hardware systems design digital electronics system organization microsoft excel
# 2oracle database administrator oracle database administrator oracle database administrator   cognizant hyderabad carrier objectiveâ to obtain a oracle dba position in a progressive company where i can utilise and enhance my experience and knowledge in constituting effectively to the success of the organization and also to improve my further technical and professional skillsâ profile summaryâ â€¢ over 4+ years of experience as architectureâ â€¢ experienced in installation and maintaining highly critical databases in any operational mode on unix linux sun solarisâ â€¢ experienced in 10g 11g 12c databasesâ â€¢ responsible for installing oracle 11g and 12c in single node  multi nodes configure host and listenerâ â€¢ experienced in creating users roles and profiles assigning roles and profiles to usersâ â€¢ experience on data guard setup 10g 11g 12câ â€¢ expertise in managing and monitoring database storage structures data files space resizing and adding new data filesâ â€¢ maintaining the cold and hot logical and rman backups of the databasesâ â€¢ performing logical backups using export utility and restoring specific object or schema using import utilityâ â€¢ monitoring and performing daily incremental backups weekly backups using rmanâ â€¢ experience in concept of flashback mechanismâ â€¢ having good and usable knowledge on automatic storage managementasm conversion of non asmâ database to asm database and monitoring asm instancesâ â€¢ experience on cloning user man and rmanâ â€¢ experience on applying patches to database cpu and psu and interim patchesâ â€¢ experience on performance tuning and troubleshooting of databaseâ â€¢ maintaining of buffer cache library cache and dictionary cacheâ â€¢ taking care of wait events analysing instance and system performanceâ â€¢ analysing the db performance using awr ash and addm reportsâ â€¢ upgrade database from 10g to 11g and 11g to 12câ â€¢ creation of asm databases asm instancesâ â â€¢ backups  recovery of databases table spaces data files design and develop database backup recovery and operations procedures sponsorship required to work in the us work experience oracle database administrator cognizant   hyderabad telangana june 2016 to present âââââââââover 4+ years of experience as architectureâ âââââââââexperienced in installation and maintaining highly critical databases in any operational mode on unix linux sun solarisâ âââââââââexperienced in 10g 11g 12c databasesâ âââââââââresponsible for installing oracle 11g and 12c in single node âmulti nodeâ€™s configure host and listenerâ âââââââââexperienced in creating users roles and profiles assigning roles and profiles to usersâ âââââââââexperience on data guard setup 10g 11g 12câ âââââââââexpertise in managing and monitoring database storage structures data files space resizing and adding new data filesâ âââââââââmaintaining the cold and hot logical and rman backups of the databasesâ âââââââââperforming logical backups using export utility and restoring specific object or schema using import utilityâ âââââââââmonitoringââandâperforming daily incremental backups weekly backups using rmanâ âââââââââexperience in concept of flashback mechanism oracle database administrator convergys   hyderabad telangana june 2014 to june 2016 education master of computer applications in science and technology jntu   kakinada andhra pradesh 2013 skills databases oracle 4 years oracle 10g sql linux rman 4 years dataguard 3 years additional information skillsâ operating systems red hat enterprise linux unixâ databases oracle 10g oracle 11g r111g r2 and 12c data guard rman asmâ languages sqlâ gui htmlâ tools  utilities dbca netca export import rman sql*plus putty
